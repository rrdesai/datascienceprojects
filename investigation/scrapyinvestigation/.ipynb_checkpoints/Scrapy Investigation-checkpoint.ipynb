# %%
import pandas as pd
import numpy as np

# %%
# !rm nytimes.json
# !scrapy crawl investigation -o nytimes.json
# Out:
# 2016-10-24 01:51:48 [scrapy] INFO: Scrapy 1.1.2 started (bot: scrapyinvestigation)
# 2016-10-24 01:51:48 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapyinvestigation.spiders', 'FEED_URI': 'nytimes.json', 'SPIDER_MODULES': ['scrapyinvestigation.spiders'], 'BOT_NAME': 'scrapyinvestigation', 'ROBOTSTXT_OBEY': True, 'FEED_FORMAT': 'json'}
# 2016-10-24 01:51:49 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-10-24 01:51:49 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-10-24 01:51:49 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-10-24 01:51:49 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-10-24 01:51:49 [scrapy] INFO: Spider opened
# 2016-10-24 01:51:49 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-10-24 01:51:49 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6024
# 2016-10-24 01:51:50 [scrapy] DEBUG: Redirecting (301) to <GET http://www.nytimes.com/robots.txt> from <GET https://www.nytimes.com/robots.txt>
# 2016-10-24 01:51:55 [scrapy] DEBUG: Crawled (200) <GET http://www.nytimes.com/robots.txt> (referer: None)
# 2016-10-24 01:52:02 [scrapy] DEBUG: Redirecting (301) to <GET http://www.nytimes.com/> from <GET https://www.nytimes.com>
# 2016-10-24 01:52:09 [scrapy] DEBUG: Crawled (200) <GET http://www.nytimes.com/> (referer: None)
# 2016-10-24 01:52:09 [scrapy] DEBUG: Scraped from <200 http://www.nytimes.com/>
# {u'Does Your Doorman Have a Hidden Talent?': u'http://www.nytimes.com/2016/10/23/realestate/does-your-doorman-have-a-hidden-talent.html', u'Economic View: I Paid $2,500 for a Hamilton Ticket. Im Happy About It.': u'http://www.nytimes.com/2016/10/23/upshot/i-paid-2500-for-a-hamilton-ticket-im-happy-about-it.html', u'Kristof: Can Trump Help Us Bridge the God Gulf?': u'http://www.nytimes.com/2016/10/23/opinion/sunday/can-trump-help-us-bridge-the-god-gulf.html', u'Books of The Times: Review: In Do Not Say We Have Nothing, a Portrait of Souls Snuffed Out': u'http://www.nytimes.com/2016/10/24/books/review-in-do-not-say-we-have-nothing-a-portrait-of-souls-snuffed-out.html', u'Cubs Defeat Dodgers to Win N.L.C.S.': u'http://www.nytimes.com/2016/10/23/sports/baseball/cubs-defeat-dodgers-reach-first-world-series-since-1945.html', u'Artificial Intelligence, and Its Criminal Potential, Evolve': u'http://www.nytimes.com/2016/10/24/technology/artificial-intelligence-evolves-with-its-criminal-potential.html', u'Review: Baryshnikov Explores the Troubled Mind of a Dance Genius': u'http://www.nytimes.com/2016/10/22/theater/review-baryshnikov-explores-the-troubled-mind-of-a-dance-genius.html', u'Debate-Watching With Hillary Clintons BFF
selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
import os

# %%
chromedriver = "/Users/R1/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)
driver.maximize_window()
url= "http://www.politico.com/2016-election/primary/results/map/president/rhode-island/"
driver.get(url)
time.sleep(10)
driver.execute_script("window.scrollTo(0,40000000000);")

# %%
counties = {}
for i in driver.find_elements_by_xpath('//article[@class = "results-group"]'):
    try:
        county = i.find_element_by_xpath('./header/div/h4').text
        print county
    except:
        continue
    candidates = {}
    for j in i.find_elements_by_xpath('./div[@class = "results-dataset"]//table[@class ="results-table"]//tr'):
        try:
            candidate = j.find_element_by_xpath('.//span[@class = "name-combo"]').text
            percent = j.find_element_by_xpath('.//span[@class = "percentage-combo"]').text
            candidates[candidate] = percent
        except:
            continue
    counties[county] = candidates
# Out:
# Bristol County
# Kent County
# Newport County
# Providence County
# Washington County

# %%
counties
# Out:
# {u'Bristol County': {u'B. Sanders': u'51.6%',
#   u'D. Trump': u'52.7%',
#   u'H. Clinton': u'47.3%',
#   u'J. Kasich': u'35.8%',
#   u'M. Rubio': u'0.9%',
#   u'M. Stewart': u'0.1%',
#   u'R. De La Fuente': u'0.0%',
#   u'T. Cruz': u'10.0%',
#   u'Uncommitted': u'0.7%'},
#  u'Kent County': {u'B. Sanders': u'58.1%',
#   u'D. Trump': u'67.4%',
#   u'H. Clinton': u'40.0%',
#   u'J. Kasich': u'22.4%',
#   u'M. Rubio': u'0.5%',
#   u'M. Stewart': u'0.2%',
#   u'R. De La Fuente': u'0.1%',
#   u'T. Cruz': u'9.2%',
#   u'Uncommitted': u'0.6%'},
#  u'Newport County': {u'B. Sanders': u'56.4%',
#   u'D. Trump': u'57.1%',
#   u'H. Clinton': u'42.5%',
#   u'J. Kasich': u'29.8%',
#   u'M. Rubio': u'0.8%',
#   u'M. Stewart': u'0.1%',
#   u'R. De La Fuente': u'0.1%',
#   u'T. Cruz': u'11.5%',
#   u'Uncommitted': u'0.8%'},
#  u'Providence County': {u'B. Sanders': u'53.6%',
#   u'D. Trump': u'68.0%',
#   u'H. Clinton': u'44.6%',
#   u'J. Kasich': u'20.4%',
#   u'M. Rubio': u'0.6%',
#   u'M. Stewart': u'0.2%',
#   u'R. De La Fuente': u'0.1%',
#   u'T. Cruz': u'10.4%',
#   u'Uncommitted': u'0.6%'},
#  u'Washington County': {u'B. Sanders': u'60.8%',
#   u'D. Trump': u'58.5%',
#   u'H. Clinton': u'37.9%',
#   u'J. Kasich': u'29.6%',
#   u'M. Rubio': u'0.5%',
#   u'M. Stewart': u'0.2%',
#   u'R. De La Fuente': u'0.1%',
#   u'T. Cruz': u'10.8%',
#   u'Uncommitted': u'0.6%'}}
